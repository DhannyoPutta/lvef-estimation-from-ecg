# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_csv('resources/reference-table.csv')
df = df["LVEF"]

# %%
bins = [10, 20, 30, 40, 50, 60, 70, 80]
bins = [5, 15, 25, 35, 45, 55, 65, 75]
plt.hist(df, bins, color='gray', edgecolor='black')
plt.xlabel('LVEF')
plt.ylabel('Number of Patients')
plt.title('Histogram of LVEF Distribution')
plt.show()
